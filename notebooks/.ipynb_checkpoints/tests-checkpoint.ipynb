# %%
node ../test/add-user.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {},
#             "error": {
#                 "error": "User \"user@testing\" already exists",
#                 "status": 500,
#                 "success": false
#             }
#         }
#     },
#     "success": false,
#     "connectorstatuscode": 500,
#     "errormessage": "Exception Error, {error:User /user@testing/ already exists,status:500,success:false}, 500, location: User user@testing already exists",
#     "autotestingenabled": false
# }

# %%
node ../test/command.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {
#                 "version": "3.4.7",
#                 "gitVersion": "cf38c1b8a0a8dca4a11737581beafef4fe120bcd",
#                 "modules": [],
#                 "allocator": "tcmalloc",
#                 "javascriptEngine": "mozjs",
#                 "sysInfo": "deprecated",
#                 "versionArray": [
#                     3,
#                     4,
#                     7,
#                     0
#                 ],
#                 "openssl": {
#                     "running": "OpenSSL 1.0.2g  1 Mar 2016",
#                     "compiled": "OpenSSL 1.0.2g  1 Mar 2016"
#                 },
#                 "buildEnvironment": {
#                     "distmod": "",
#                     "distarch": "x86_64",
#                     "cc": "cc: cc (Ubuntu 7.1.0-13ubuntu1) 7.1.0",
# ...

# %%
node ../test/ping.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {},
#             "error": {}
#         }
#     },
#     "success": true,
#     "connectorstatuscode": 200,
#     "errormessage": "",
#     "autotestingenabled": false
# }

# %%
node ../test/rep-i-set-get-status.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {},
#             "error": {
#                 "error": "not running with --replSet",
#                 "status": 500,
#                 "success": false
#             }
#         }
#     },
#     "success": false,
#     "connectorstatuscode": 500,
#     "errormessage": "Exception Error, {error:not running with --replSet,status:500,success:false}, 500, location: not running with --replSet",
#     "autotestingenabled": false
# }

# %%
node ../test/server-status.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {
#                 "host": "nativapps-ideacentre-AIO-700-24ISH",
#                 "version": "3.4.7",
#                 "process": "mongod",
#                 "pid": 857,
#                 "uptime": 92813,
#                 "uptimeMillis": 92814686,
#                 "uptimeEstimate": 92814,
#                 "localTime": "2017-12-29T14:04:28.838Z",
#                 "asserts": {
#                     "regular": 0,
#                     "warning": 0,
#                     "msg": 0,
#                     "user": 19,
#                     "rollovers": 0
#                 },
#                 "connections": {
#                     "current": 2,
#                     "available": 817,
#                     "totalCreated": 171
#                 },
#                 "extra_info": {
#                     "note": "fields vary by platform",
#                     "page_faults": 305
#                 },
# ...

# %%
node ../test/validate-collection.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {
#                 "ns": "test.users",
#                 "nrecords": 2,
#                 "nIndexes": 1,
#                 "keysPerIndex": {
#                     "test.users.$_id_": 2
#                 },
#                 "valid": true,
#                 "warnings": [
#                     "Some checks omitted for speed. use {full:true} option to do more thorough scan."
#                 ],
#                 "errors": [],
#                 "ok": 1
#             },
#             "error": {}
#         }
#     },
#     "success": true,
#     "connectorstatuscode": 200,
#     "errormessage": "",
#     "autotestingenabled": false
# }

# %%
node ../test/build-info.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {
#                 "version": "3.4.7",
#                 "gitVersion": "cf38c1b8a0a8dca4a11737581beafef4fe120bcd",
#                 "modules": [],
#                 "allocator": "tcmalloc",
#                 "javascriptEngine": "mozjs",
#                 "sysInfo": "deprecated",
#                 "versionArray": [
#                     3,
#                     4,
#                     7,
#                     0
#                 ],
#                 "openssl": {
#                     "running": "OpenSSL 1.0.2g  1 Mar 2016",
#                     "compiled": "OpenSSL 1.0.2g  1 Mar 2016"
#                 },
#                 "buildEnvironment": {
#                     "distmod": "",
#                     "distarch": "x86_64",
#                     "cc": "cc: cc (Ubuntu 7.1.0-13ubuntu1) 7.1.0",
# ...

# %%
node ../test/list-databases.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": [
#                 {
#                     "name": "admin",
#                     "sizeOnDisk": 147456,
#                     "empty": false
#                 },
#                 {
#                     "name": "local",
#                     "sizeOnDisk": 73728,
#                     "empty": false
#                 },
#                 {
#                     "name": "test",
#                     "sizeOnDisk": 81920,
#                     "empty": false
#                 }
#             ],
#             "error": {}
#         }
#     },
#     "success": true,
#     "connectorstatuscode": 200,
#     "errormessage": "",
#     "autotestingenabled": false
# }

# %%
node ../test/remove-user.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {
#                 "response": "User has ben deleted."
#             },
#             "error": {}
#         }
#     },
#     "success": true,
#     "connectorstatuscode": 200,
#     "errormessage": "",
#     "autotestingenabled": false
# }

# %%
node ../test/server-info.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {
#                 "version": "3.4.7",
#                 "gitVersion": "cf38c1b8a0a8dca4a11737581beafef4fe120bcd",
#                 "modules": [],
#                 "allocator": "tcmalloc",
#                 "javascriptEngine": "mozjs",
#                 "sysInfo": "deprecated",
#                 "versionArray": [
#                     3,
#                     4,
#                     7,
#                     0
#                 ],
#                 "openssl": {
#                     "running": "OpenSSL 1.0.2g  1 Mar 2016",
#                     "compiled": "OpenSSL 1.0.2g  1 Mar 2016"
#                 },
#                 "buildEnvironment": {
#                     "distmod": "",
#                     "distarch": "x86_64",
#                     "cc": "cc: cc (Ubuntu 7.1.0-13ubuntu1) 7.1.0",
# ...

# %%
node ../test/set-profiling-level.js
# Out:
# {
#     "response": {
#         "outputs": {
#             "output": {},
#             "error": {}
#         }
#     },
#     "success": false,
#     "connectorstatuscode": 200,
#     "errormessage": "The response must be a valid JSON: [object Object]",
#     "autotestingenabled": false
# }
